# %%
from langchain_community.document_loaders import ScrapingAntLoader
from bs4 import BeautifulSoup
import pandas as pd

scrapingLoader = ScrapingAntLoader(
    ["https://www.naukri.com/ai-engineer-jobs?k=ai%20engineer"],
    api_key="5506adfd15b5468a816c4d20eb2fdbb4",
    continue_on_failure=True
)
documents = scrapingLoader.load()
# Out:
# [Document(metadata={'url': 'https://naukri.com'}, page_content='[![Naukri Logo](https://static.naukimg.com/s/0/0/i/naukri-\nidentity/naukri_gnb_logo.svg)](https://www.naukri.com)\n\n  * [Jobs](https://www.naukri.com "Search Jobs")\n\n    * Popular categories\n    * [IT jobs](https://www.naukri.com/it-jobs?src=gnbjobs_homepage_srch "IT jobs")\n    * [Sales jobs](https://www.naukri.com/sales-jobs?src=gnbjobs_homepage_srch "Sales jobs")\n    * [Marketing jobs](https://www.naukri.com/marketing-jobs?src=gnbjobs_homepage_srch "Marketing jobs")\n    * [Data Science jobs](https://www.naukri.com/data-science-jobs?src=gnbjobs_homepage_srch "Data Science jobs")\n    * [HR jobs](https://www.naukri.com/hr-jobs?src=gnbjobs_homepage_srch "HR jobs")\n    * [Engineering jobs](https://www.naukri.com/engineering-jobs?src=gnbjobs_homepage_srch "Engineering jobs")\n    * Jobs in demand\n    * [Fresher jobs](https://www.naukri.com/fresher-jobs?src=gnbjobs_homepage_srch "Fresher jobs")\n    * [MNC jobs](https://www.naukri.com/mnc-jobs?src=gnbjobs_homepage_srch "MNC jobs")\n    * [Remote jobs](https://www.naukri.com/remote-jobs?src=gnbjobs_homepage_srch "Remote jobs")\n    * [Work from home jobs](https://www.naukri.com/work-from-home-jobs?src=gnbjobs_homepage_srch "Work from home jobs")\n    * [Walk-in jobs](https://www.naukri.com/walkin-jobs?src=gnbjobs_homepage_srch "Walk-in jobs")\n    * [Part-time jobs](https://www.naukri.com/part-time-jobs?src=gnbjobs_homepage_srch "Part-time jobs")\n    * Jobs by location\n    * [Jobs in Delhi](https://www.naukri.com/jobs-in-delhi-ncr "Jobs in Delhi")\n    * [Jobs in Mumbai](https://www.naukri.com/jobs-in-mumbai "Jobs in Mumbai")\n    * [Jobs in Bangalore](https://www.naukri.com/jobs-in-bangalore "Jobs in Bangalore")\n    * [Jobs in Hyderabad](https://www.naukri.com/jobs-in-hyderabad-secunderabad "Jobs in Hyderabad")\n    * [Jobs in Chennai](https://www.naukri.com/jobs-in-chennai "Jobs in Chennai")\n    * [Jobs in Pune](https://www.naukri.com/jobs-in-pune "Jobs in Pune")\n\n  * [Companies](https://www.naukri.com/companies-hiring-in-india?src=gnbCompanies_homepage_srch "Explore top companies hiring on Naukri")\n\n    * Explore categories\n    * [Unicorn](https://www.naukri.com/unicorn-companies-in-india-cat102?title=Unicorns%20actively%20hiring&src=gnbCompanies_homepage_srch "Unicorn")\n    * [MNC](https://www.naukri.com/mnc-companies-in-india-cat101?title=MNCs%20actively%20hiring&src=gnbCompanies_homepage_srch "MNC")\n    * [Startup](https://www.naukri.com/startup-companies-in-india-cat103?title=Startups%20actively%20hiring&src=gnbCompanies_homepage_srch "Startup")\n    * [Product based](https://www.naukri.com/product-companies-in-india-cat106?title=Product%20companies%20actively%20hiring&src=gnbCompanies_homepage_srch "Product based")\n    * [Internet](https://www.naukri.com/internet-companies-in-india-cat105?title=Internet%20companies%20actively%20hiring&src=gnbCompanies_homepage_srch "Internet")\n    * Explore collections\n    * [Top companies](https://www.naukri.com/companies-hiring-in-india?src=gnbCompanies_homepage_srch "Top companies")\n    * [IT companies](https://www.naukri.com/it-companies-in-india-cat116?src=gnbCompanies_homepage_srch&title=IT%20Companies%20Hiring "IT companies")\n    * [Fintech companies](https://www.naukri.com/fintech-and-payments-companies-in-india-cat108?title=Fintech%20%26%20Payments%20companies%20actively%20hiring&src=gnbCompanies_homepage_srch "Fintech companies")\n    * [Sponsored companies](https://www.naukri.com/allcompanies?searchType=standardLogo&title=Sponsored+companies&branding=%257B%2522pagename%2522%253A%2522ni-desktop-standard-viewAll%2522%257D&pageNo=1&qcount=47&src=gnbCompanies_homepage_srch "Sponsored companies")\n    * [Featured companies](https://www.naukri.com/allcompanies?searchType=premiumLogo&title=Featured+companies+actively+hiring&branding=%257B%2522pagename%2522%253A%2522ni-desktop-premium-viewAll%2522%257D&pageNo=1&qcount=47&src=gnbCompanies_homepage_sr ...

# %%
html = documents[0].page_content
soup = BeautifulSoup(html, "html.parser")

job_cards = soup.find_all("articles")

result = []

# %%
for card in job_cards:
    try:
        title_tage = card.find("a", class_="title")
        job_title = title_tage.text.strip()
        link = title_tage["href"].strip()

        company = card.find("span", class_="companyName").text.strip()
        location = card.find("li", class_="location").text.strip()

        #Extract job description (short summary insiide <ul>)
        description_item = card.find("ul", class_="job-description")
        if description_item:
            description = " | ".join(li.text.strip() for li in description_item.find_all("li"))
        else:
            description = "N/A"

        result.append({
            "Job Title": job_title,
            "Company" : company,
            "Location": location,
            "Description": description,
            "Link": link
                            })
    except Exception:
        continue

# %%
df = pd.DataFrame(result)
pd.set_option("display.max_colwidth", None)
print(df.head(10))
